# %% [markdown]
# # Lab 1 — First contact: talking to a model, and measuring it
#
# **Artificial Intelligence · 4th year · UIR · Pr. Hakim Hafidi**
#
# | | |
# |---|---|
# | **Duration** | 2 hours, individual work |
# | **You will learn** | how to call a model from Colab without exposing your key · how to read what a call costs (tokens, latency, money) · how to compare two models on a task from your own field |
# | **Deliverable** | this notebook, executed, + the `lab01_<your id>.json` file it generates, both submitted on connect.uir.ac.ma |
# | **Grading** | 4 points: it runs (1) · measurements are correct (1) · interpretation (1) · critical analysis (1) |
#
# > **Rule for the whole semester:** never paste an API key into a notebook cell.
# > You will use Colab Secrets instead — step 1 below.

# %% [markdown]
# ---
# ## Step 0 — Get your API key (10 minutes)
#
# 1. Go to **https://aistudio.google.com/apikey** and sign in with your Google account.
# 2. Click **Create API key**. No credit card is needed. Copy the key.
# 3. In this notebook, open the **🔑 key icon** in the left sidebar → **+ Add new secret**:
#    - **Name:** `GEMINI_API_KEY`
#    - **Value:** paste your key
#    - Switch **Notebook access** ON.
# 4. Run the two cells below.
#
# *If anything fails, raise your hand — do not spend ten minutes alone on it.*

# %%
# Install the libraries this lab needs (~30 seconds)
# %pip install -q google-genai pandas
print("done")
# Out:
# done

# %%
#@title ⚙️ Toolbox — run this cell once, then fold it { display-mode: "form" }
# =============================================================================
#  AI course · UIR · shared lab toolbox  (v1)
#  You do not need to modify this cell. Read it once — you will use ask() all
#  semester. It handles: the API key, caching, rate limits, and measurement.
# =============================================================================
import os, re, json, time, hashlib, pathlib, textwrap
from dataclasses import dataclass, asdict

# --- Models available on the Gemini free tier --------------------------------
# Names change every few months. If a call fails with "model not found",
# check https://ai.google.dev/gemini-api/docs/models and update these two lines.
MODEL_FAST   = "gemini-3.5-flash-lite"   # cheapest, highest daily quota
MODEL_STRONG = "gemini-3.5-flash"        # better, lower quota

# Public prices, USD per 1M tokens — used to *simulate* what your calls cost.
PRICES = {
    "gemini-3.5-flash-lite": (0.10, 0.40),
    "gemini-3.5-flash":      (0.30, 2.50),
}

CACHE_DIR = pathlib.Path("/content/.ai_cache"); CACHE_DIR.mkdir(exist_ok=True, parents=True)
CALL_LOG  = []          # every call made in this session
USE_LOCAL_FALLBACK = False   # set to True only if your API key does not work

@dataclass
class Answer:
    text: str; model: str; temperature: float
    in_tokens: int; out_tokens: int; latency_s: float; cost_usd: float
    cached: bool = False
    def __str__(self): return self.text
    def __repr__(self): return self.text

def _api_key():
    """Read the key from Colab Secrets (preferred) or an env variable."""
    try:
        from google.colab import userdata
        k = userdata.get("GEMINI_API_KEY")
        if k: return k.strip()
    except Exception:
        pass
    return (os.environ.get("GEMINI_API_KEY") or "").strip()

_client = None
def _client_once():
    global _client
    if _client is None:
        from google import genai
        key = _api_key()
        if not key:
            raise RuntimeError(
                "No API key found. Add it in Colab: 🔑 (left sidebar) → + New secret →\n"
                "  Name: GEMINI_API_KEY   Value: <your key>   → enable 'Notebook access'."
            )
        _client = genai.Client(api_key=key)
    return _client

# --- Emergency fallback: a small open model running locally in Colab ---------
_local = None
def _local_once():
    global _local
    if _local is None:
        print("⚠️  Loading a small local model (slow, low quality — emergency use only)…")
        from transformers import pipeline
        _local = pipeline("text-generation", model="Qwen/Qwen2.5-0.5B-Instruct",
                          max_new_tokens=300, do_sample=True)
    return _local

def _cache_path(payload):
    return CACHE_DIR / (hashlib.sha256(json.dumps(payload, sort_keys=True).encode()).hexdigest()[:24] + ".json")

def ask(prompt, model=MODEL_FAST, temperature=0.0, max_tokens=800,
        system=None, use_cache=True, retries=5, verbose=False):
    """Send one prompt to a model and return an Answer.

    ask("Hello")                          -> fast model, temperature 0
    ask("Hello", model=MODEL_STRONG)      -> stronger model
    ask("Hello", temperature=1.5)         -> more random
    ask("Hello", use_cache=False)         -> force a real call (costs quota!)

    Results are cached on disk: re-running a cell with the same prompt and the
    same settings is free and instant. That is why your notebook can be
    re-executed from top to bottom without burning your daily quota.
    """
    key = {"p": prompt, "m": model, "t": temperature, "mt": max_tokens, "s": system}
    cp = _cache_path(key)
    if use_cache and cp.exists():
        d = json.loads(cp.read_text()); d["cached"] = True
        a = Answer(**d); CALL_LOG.append(asdict(a)); return a

    if USE_LOCAL_FALLBACK:
        t0 = time.time()
        out = _local_once()(prompt, temperature=max(temperature, 0.01))[0]["generated_text"]
        txt = out[len(prompt):].strip() if out.startswith(prompt) else out.strip()
        a = Answer(txt, "local-fallback", temperature, len(prompt)//4, len(txt)//4, time.time()-t0, 0.0)
        CALL_LOG.append(asdict(a)); return a

    from google.genai import types
    cfg = types.GenerateContentConfig(temperature=temperature, max_output_tokens=max_tokens,
                                      system_instruction=system)
    delay = 2.0
    for attempt in range(retries):
        try:
            t0 = time.time()
            r = _client_once().models.generate_content(model=model, contents=prompt, config=cfg)
            dt = time.time() - t0
            u  = getattr(r, "usage_metadata", None)
            ti = getattr(u, "prompt_token_count", 0) or 0
            to = getattr(u, "candidates_token_count", 0) or 0
            pi, po = PRICES.get(model, (0.0, 0.0))
            a = Answer((r.text or "").strip(), model, temperature, ti, to, round(dt, 2),
                       round(ti/1e6*pi + to/1e6*po, 6))
            cp.write_text(json.dumps({k: v for k, v in asdict(a).items() if k != "cached"}))
            CALL_LOG.append(asdict(a))
            if verbose: print(f"[{model}] {ti}→{to} tokens · {dt:.2f}s")
            return a
        except Exception as e:
            msg = str(e)
            if any(s in msg for s in ("429", "RESOURCE_EXHAUSTED", "quota", "503", "UNAVAILABLE")):
                print(f"⏳ rate limit or server busy — waiting {delay:.0f}s "
                      f"(attempt {attempt+1}/{retries}). Free tier is ~15 calls/minute.")
                time.sleep(delay); delay *= 2; continue
            raise
    raise RuntimeError("Still rate-limited after several retries. Wait a minute, or use the cache.")

def usage_report():
    """Print what this session has cost you so far."""
    import pandas as pd
    if not CALL_LOG: print("No calls yet."); return None
    df = pd.DataFrame(CALL_LOG)
    real = df[~df.cached]
    print(f"calls: {len(df)}  (real: {len(real)}, from cache: {int(df.cached.sum())})")
    print(f"tokens in/out: {int(real.in_tokens.sum())} / {int(real.out_tokens.sum())}")
    print(f"time spent waiting: {real.latency_s.sum():.1f}s    simulated cost: ${real.cost_usd.sum():.5f}")
    return df

def check_environment():
    """Verify that everything needed for this lab is available."""
    ok = True
    try:
        import google.genai; print("✅ google-genai installed")
    except ImportError:
        print("❌ google-genai missing — run the install cell above"); ok = False
    if _api_key(): print("✅ API key found")
    else: print("❌ API key not found — see the instructions above"); ok = False
    try:
        a = ask("Reply with exactly: OK", max_tokens=10)
        print(f"✅ model answered: {a.text[:40]!r}")
    except Exception as e:
        print(f"❌ call failed: {str(e)[:200]}"); ok = False
    print("\n" + ("🎉 You are ready." if ok else "⚠️  Fix the ❌ above, then re-run this cell."))
    return ok

def export_lab(lab_id, student_id, answers: dict, tables: dict = None, extra: dict = None):
    """Build the file you submit on connect.uir.ac.ma."""
    import pandas as pd
    student_id = str(student_id).strip()
    assert student_id and student_id.lower() not in ("", "xxxxx", "your_id"), \
        "Set STUDENT_ID to your real apogee number."
    payload = {"lab": lab_id, "student_id": student_id,
               "answers": {k: str(v).strip() for k, v in answers.items()},
               "tables": {k: (v.to_dict("records") if hasattr(v, "to_dict") else v)
                          for k, v in (tables or {}).items()},
               "extra": extra or {},
               "call_log": CALL_LOG,
               "created": time.strftime("%Y-%m-%d %H:%M")}
    name = f"{lab_id}_{student_id}.json"
    pathlib.Path(name).write_text(json.dumps(payload, indent=2, ensure_ascii=False))
    empty = [k for k, v in payload["answers"].items() if len(v) < 40]
    print(f"📦 {name} written ({pathlib.Path(name).stat().st_size} bytes)")
    if empty: print(f"⚠️  These answers look too short: {empty}")
    else:     print("✅ All answers filled.")
    print("\nSubmit BOTH files on connect.uir.ac.ma:")
    print(f"   1. this notebook (File → Download → .ipynb)\n   2. {name}")
    return payload

print("✅ Toolbox loaded. Main function: ask(prompt, model=…, temperature=…)")
print(f"   Models: MODEL_FAST={MODEL_FAST!r}  MODEL_STRONG={MODEL_STRONG!r}")
# Out:
# ✅ Toolbox loaded. Main function: ask(prompt, model=…, temperature=…)
#    Models: MODEL_FAST='gemini-3.5-flash-lite'  MODEL_STRONG='gemini-3.5-flash'

# %% [markdown]
# ---
# ## Step 1 — Check that everything works
#
# The cell below sends one small prompt. If you see ✅ three times, you are ready.

# %%
check_environment()
# Out:
# ✅ google-genai installed
# ✅ API key found
# ✅ model answered: 'OK'
#
# 🎉 You are ready.
# True

# %% [markdown]
# ---
# ## Part A — The knobs (20 minutes)
#
# `ask()` is the only function you need. Read its three lines of documentation:
#
# ```python
# ask("Hello")                      # fast model, temperature 0
# ask("Hello", model=MODEL_STRONG)  # stronger model
# ask("Hello", temperature=1.5)     # more random
# ```
#
# Run the next cell as it is, and look at what the model answered **and** at what it cost.

# %%
a = ask("In one sentence, what is a language model?")
print(a.text)
print()
print(f"model      : {a.model}")
print(f"tokens     : {a.in_tokens} in → {a.out_tokens} out")
print(f"latency    : {a.latency_s} s")
print(f"cost       : ${a.cost_usd:.6f}   (simulated at public prices)")
print(f"from cache : {a.cached}")
# Out:
# A language model is an AI system trained on vast amounts of text to predict, generate, and understand human language based on statistical patterns.
#
# model      : gemini-3.5-flash-lite
# tokens     : 11 in → 27 out
# latency    : 0.58 s
# cost       : $0.000012   (simulated at public prices)
# from cache : False

# %% [markdown]
# ### A.1 — Does the same question give the same answer?
#
# Ask **the same question three times at temperature 0**, then **three times at temperature 1.5**.
# Look at whether the answers are identical.
#
# > ⚠️ `ask()` caches results: the same prompt with the same settings returns the *stored*
# > answer instantly. To force real calls, pass `use_cache=False`.

# %%
QUESTION = "Give me one original idea for a student project about AI in agriculture."

cold, hot = [], []
for i in range(3):
    # TODO (2 lines): call ask() with temperature=0.0, then with temperature=1.5.
    #                 Use use_cache=False so that each call is a real one.
    #                 Append the .text of each answer to `cold` and `hot`.
    cold.append(ask(QUESTION, use_cache=False).text)
    hot.append(ask(QUESTION, temperature=1.5, use_cache=False).text)

assert all(isinstance(t, str) for t in cold + hot),     "Fill the two TODO lines above: cold.append(ask(...).text)"

print("TEMPERATURE 0.0")
for t in cold: print(" -", t[:110].replace("\n", " "), "…")
print("\nTEMPERATURE 1.5")
for t in hot:  print(" -", t[:110].replace("\n", " "), "…")

print(f"\ndistinct answers at T=0.0 : {len(set(cold))}/3")
print(f"distinct answers at T=1.5 : {len(set(hot))}/3")
# Out:
# TEMPERATURE 0.0
#  - **Project Title:** *“AgroEcho: Acoustic Crop Health Monitoring using Edge AI”*  ### The Concept Instead of usi …
#  - **Project Title:** *“BuzzWatch: Acoustic AI for Early Colony Collapse & Disease Detection in Backyard Beehives …
#  - **Project Title:** *Micro-Livestock Guardian: Acoustic Monitoring of Stress and Disease in Backyard Poultry/Sm …
#
# TEMPERATURE 1.5
#  - **Project Title:** *“AgriSound: Acoustic Monitoring of Crop Health and Pest Infestation Using Edge AI”*  ### T …
#  - **Project Title:** *“AgroEcho: Acoustic Crop Health Monitoring via Edge-AI”*  ### The Concept Instead of using …
#  - **Project Title:** *“AgroEcho: Acoustic Crop Health Monitoring Using Edge AI”*  ### The Core Idea Instead of u …
#
# distinct answers at T=0.0 : 3/3
# distinct answers at T=1.5 : 3/3

# %%
assert len(cold) == 3 and len(hot) == 3, "You need 3 answers at each temperature."
assert all(isinstance(t, str) and len(t) > 20 for t in cold + hot), "Store the .text, not the Answer object."
print("✅ A.1 done — write down what you observed, you will need it in Part C.")
# Out:
# ✅ A.1 done — write down what you observed, you will need it in Part C.

# %% [markdown]
# ---
# ## Part B — Your task, two models (30 minutes)
#
# Pick **one** task that is realistic for your own field, from these five starting points:
#
# | | Task | Example |
# |---|---|---|
# | 1 | Summarize a technical text | a page of a standard, a paper abstract, a regulation |
# | 2 | Extract information from a document | dates, amounts, names, parties in a contract |
# | 3 | Explain a concept to a non-specialist | explain a notion of your speciality to a 15-year-old |
# | 4 | Classify short messages | customer feedback, support tickets, survey answers |
# | 5 | Write a short piece of code | a SQL query, a data-cleaning script |
#
# Then write **one prompt** for it. Do not spend more than five minutes on the prompt — a
# whole session (Lab 6) is devoted to making prompts good. Here we only need a prompt that works.

# %%
# TODO (3–6 lines): describe your task and write your prompt.
#   MY_TASK  : one sentence, in English, saying what the task is.
#   MY_PROMPT: the actual text you send to the model. Include the input it must work on
#              (a paragraph you paste, a list of messages, a schema… ).

MY_TASK = "Recap FC Barcelona's Champions League exits every season since 2015/16 and analyse why they keep failing to win a 6th title."

MY_PROMPT = """
List, for FC Barcelona, every UEFA Champions League campaign from the 2015/16 season through the 2025/26 season. For each season give exactly: the season, the round in which Barcelona were eliminated, and the club that eliminated them. Present it as one line per season. Then, in 3 to 4 sentences, identify the recurring pattern behind these eliminations. Be precise if you are not sure about a specific season, say so instead of guessing.
"""

assert len(MY_TASK) > 20 and len(MY_PROMPT) > 120, "Write a real task and a real prompt."
print(f"Task   : {MY_TASK}")
print(f"Prompt : {len(MY_PROMPT)} characters")
# Out:
# Task   : Recap FC Barcelona's Champions League exits every season since 2015/16 and analyse why they keep failing to win a 6th title.
# Prompt : 441 characters

# %% [markdown]
# ### B.1 — Run it on both models, three times each
#
# The loop is written for you. You only fill in the two model names and the temperature.
# This makes **6 real calls** — that is fine, the free tier allows about 15 per minute.

# %%
import pandas as pd

rows = []
for model in [MODEL_FAST, MODEL_STRONG]:
    for run in range(3):
        # TODO (1 line): call ask() with MY_PROMPT, the current `model`,
        #                temperature=0.7, and use_cache=False.
        a = ask(MY_PROMPT, model, temperature=0.7, use_cache=False)
        assert hasattr(a, "text"), "Fill the TODO line above: a = ask(MY_PROMPT, ...)"
        rows.append({"model": model, "run": run + 1, "answer": a.text,
                     "in_tokens": a.in_tokens, "out_tokens": a.out_tokens,
                     "latency_s": a.latency_s, "cost_usd": a.cost_usd})

results = pd.DataFrame(rows)
print(results[["model", "run", "in_tokens", "out_tokens", "latency_s", "cost_usd"]].to_string(index=False))
# Out:
#                 model  run  in_tokens  out_tokens  latency_s  cost_usd
# gemini-3.5-flash-lite    1        106         364       1.88  0.000156
# gemini-3.5-flash-lite    2        106         352       1.79  0.000151
# gemini-3.5-flash-lite    3        106         359       1.71  0.000154
#      gemini-3.5-flash    1        106          32       4.68  0.000112
#      gemini-3.5-flash    2        106          32       7.34  0.000112
#      gemini-3.5-flash    3        106          32       3.72  0.000112

# %%
# TODO (2–4 lines): build a summary table with, for each model, the MEAN of
#   out_tokens, latency_s and cost_usd over the 3 runs.
#   Hint: results.groupby("model")[[...]].mean().round(6)
#   Costs per call are tiny — keep 6 decimals, or you will read 0.0 everywhere.

summary = results.groupby("model")[["out_tokens", "latency_s", "cost_usd"]].mean().round(6)

# Given to you: what 1000 calls would cost — the number that actually matters.
summary["cost_per_1000_calls"] = (summary["cost_usd"] * 1000).round(2)

print(summary)
# Out:
#                        out_tokens  latency_s  cost_usd  cost_per_1000_calls
# model
# gemini-3.5-flash        32.000000   5.246667  0.000112                 0.11
# gemini-3.5-flash-lite  358.333333   1.793333  0.000154                 0.15

# %%
# Read two answers side by side — one per model — and judge them yourself.
for model in [MODEL_FAST, MODEL_STRONG]:
    print("=" * 78)
    print(model)
    print("=" * 78)
    print(results[results.model == model].iloc[0].answer[:1200])
    print()
# Out:
# ==============================================================================
# gemini-3.5-flash-lite
# ==============================================================================
# 2015/16: Eliminated in the Quarter-finals by Atlético Madrid
# 2016/17: Eliminated in the Quarter-finals by Juventus
# 2017/18: Eliminated in the Quarter-finals by Roma
# 2018/19: Eliminated in the Semi-finals by Liverpool
# 2019/20: Eliminated in the Quarter-finals by Bayern Munich
# 2020/21: Eliminated in the Round of 16 by Paris Saint-Germain
# 2021/22: Eliminated in the Group stage (dropped to Europa League), though technically eliminated from the Champions League by Bayern Munich and Benfica
# 2022/23: Eliminated in the Group stage (dropped to Europa League), though technically eliminated from the Champions League by Bayern Munich and Inter Milan
# 2023/24: Eliminated in the Quarter-finals by Paris Saint-Germain
# 2024/25: *Uncertain / Season not yet completed or fully played at the time of this prompt's scope*
# 2025/26: *Uncertain / Season not yet completed or fully played at the time of this prompt's scope*
#
# A recurring pattern behind Barcelona's modern Champions League eliminations is their vulnerability to historic collapses, often referred to as "remontadas," where commanding aggregate leads or promising positions are dramatically squandered away from home. In many of these high-profile exi
#
# ==============================================================================
# gemini-3.5-flash
# ==============================================================================
# Here is the list of FC Barcelona’s UEFA Champions League campaigns from the 2015/16 season through the 2025/

# %%
assert len(results) == 6, "You need 3 runs on each of the 2 models."
assert hasattr(summary, "shape"), "summary is still the placeholder `...` — build the table."
assert len(summary) == 2, "summary must have exactly one row per model."
assert results.out_tokens.sum() > 0, "Token counts are zero — did the calls really run?"
print("✅ Part B done.")
# Out:
# ✅ Part B done.

# %% [markdown]
# ---
# ## Part C — Tokens are not words (10 minutes)
#
# One more measurement before the questions. The model does not read words, it reads
# **tokens**. Let's see what that costs in different languages.

# %%
SENTENCES = {
    "English": "Artificial intelligence is changing how engineers work every day.",
    "French":  "L'intelligence artificielle change la façon dont les ingénieurs travaillent chaque jour.",
    "Arabic":  "الذكاء الاصطناعي يغير طريقة عمل المهندسين كل يوم.",
}

rows = []
for lang, sentence in SENTENCES.items():
    # TODO (1 line): send the sentence to the model with max_tokens=5 and read a.in_tokens.
    #   We only care about how many tokens the INPUT takes, not about the answer.
    a = ask(sentence, max_tokens=5)
    assert hasattr(a, "in_tokens"), "Fill the TODO line above: a = ask(sentence, max_tokens=5, ...)"
    rows.append({"language": lang, "characters": len(sentence),
                 "words": len(sentence.split()), "input_tokens": a.in_tokens})

tokens = pd.DataFrame(rows)
tokens["tokens_per_word"] = (tokens.input_tokens / tokens.words).round(2)
print(tokens.to_string(index=False))
# Out:
# language  characters  words  input_tokens  tokens_per_word
#  English          65      9            11             1.22
#   French          88     11            18             1.64
#   Arabic          49      8            18             2.25

# %%
assert len(tokens) == 3 and tokens.input_tokens.min() > 0, "The three measurements must be real."
print("✅ Measurement done. Look at the last column before answering Q3.")
# Out:
# ✅ Measurement done. Look at the last column before answering Q3.

# %% [markdown]
# ---
# ## Part D — Analysis (20 minutes)
#
# Answer in the cell below, **in English, in your own words**, using your own numbers.
# Two or three sentences each. This is where most of the grade is.

# %%
STUDENT_ID = "130588"   # TODO: your apogee number

# Q1 — Same prompt, same settings, run three times. Were the answers identical at
#      temperature 0? At 1.5? Quote two concrete differences you saw.
Q1 = """
the answers were not identical at temperature 0 : the three runs produced three different projects : "AgroEcho", "BuzzWatch" and "Micro-Livestock Guardian", 3/3 distinct. At T=1.5 the runs were also 3/3 distinct but paradoxically closer in substance: two converged on almost the same title ("AgroEcho — Acoustic Crop Health Monitoring using Edge AI"), varying in context. Two concrete differences: (1) at T=0 the project topic changed run to run while at T=1.5 the topic stayed fixed and only the wording moved; (2) at T=1.5 the title stayed the same.
"""

# Q2 — For YOUR task: which of the two models would you use, and why? Justify with at
#      least two of the five criteria from the course (quality, cost, latency, privacy, control)
#      and with your measured numbers (latency, cost per 1000 calls, answer length).
Q2 = """
For my task (recap of Barcelona's Champions League exits) I would use gemini-3.5-flash-lite, on quality and latency. Quality: flash-lite returned the full season-by-season list plus the analysis (358 output tokens on average), while flash was truncated mid-sentence at exactly 32 output tokens on every run. Latency: flash-lite averaged 1.79 s against 5.25 s for flash, about 3 times faster even producing far more text. On cost the two are nearly equal ($0.15 vs $0.11 per 1000 calls), and flash only looks cheaper because it stopped early, its lower cost is an artefact of a broken answer, not a real advantage. Here the smaller, cheaper model is clearly the better choice in this case.
"""

# Q3 — Look at the tokens_per_word column. Which language costs most per word, and by
#      roughly what factor? What practical consequence does that have for a Moroccan
#      company that wants to deploy an assistant in Arabic?
Q3 = """
Arabic costs the most per word: 2.25 tokens/word, against 1.64 for French and 1.22 for English — about 1.8 times (nearly double) the English rate. The Arabic sentence was the shortest in both characters (49) and words (8) and still needed 18 tokens, as many as the longer French one, because the tokenizer is English-centric and breaks Arabic script into many sub-word pieces. Practical consequence for a Moroccan company deploying an Arabic assistant: every interaction consumes roughly twice the tokens of its English equivalent, so it costs about two times more per request, fills the context window faster and can be slower. Arabic-language AI is structurally more expensive to run, and that must be budgeted for.
"""

# Q4 — Name ONE thing about the quality of the answers that your method could NOT
#      measure. How would you measure it properly?
Q4 = """
My method never measured if the model told the truth. I only logged answer length, latency and cost, and read the text by eye, nothing in the code checks, rounds and opponents were correct.
"""

# %%
answers = {"Q1": Q1, "Q2": Q2, "Q3": Q3, "Q4": Q4}
problems = []
if STUDENT_ID.strip().upper() in ("XXXXX", ""): problems.append("STUDENT_ID is not filled in")
for k, v in answers.items():
    if len(v.strip()) < 120: problems.append(f"{k} is too short (write 2–3 sentences)")
    if "..." in v:           problems.append(f"{k} still contains the placeholder")
if problems:
    print("⚠️  Not ready to submit:"); [print("   -", p) for p in problems]
else:
    print("✅ Everything looks complete. Run the export cell below.")
# Out:
# ✅ Everything looks complete. Run the export cell below.

# %% [markdown]
# ---
# ## Submit
#
# Run the cell below, then upload **both** the notebook and the `.json` file on connect.uir.ac.ma.

# %%
usage_report()
print()
export_lab("lab01", STUDENT_ID,
           answers={"Q1": Q1, "Q2": Q2, "Q3": Q3, "Q4": Q4},
           tables={"comparison": results.drop(columns=["answer"]),
                   "summary": summary.reset_index(),
                   "tokens": tokens},
           extra={"task": MY_TASK, "prompt": MY_PROMPT,
                  "distinct_T0": len(set(cold)), "distinct_T15": len(set(hot))})
# Out:
# calls: 17  (real: 17, from cache: 0)
# tokens in/out: 790 / 3888
# time spent waiting: 104.6s    simulated cost: $0.00190
#
# 📦 lab01_130588.json written (26247 bytes)
# ✅ All answers filled.
#
# Submit BOTH files on connect.uir.ac.ma:
#    1. this notebook (File → Download → .ipynb)
#    2. lab01_130588.json
# {'lab': 'lab01',
#  'student_id': '130588',
#  'answers': {'Q1': 'the answers were not identical at temperature 0 : the three runs produced three different projects : "AgroEcho", "BuzzWatch" and "Micro-Livestock Guardian", 3/3 distinct. At T=1.5 the runs were also 3/3 distinct but paradoxically closer in substance: two converged on almost the same title ("AgroEcho — Acoustic Crop Health Monitoring using Edge AI"), varying in context. Two concrete differences: (1) at T=0 the project topic changed run to run while at T=1.5 the topic stayed fixed and only the wording moved; (2) at T=1.5 the title stayed the same.',
#   'Q2': "For my task (recap of Barcelona's Champions League exits) I would use gemini-3.5-flash-lite, on quality and latency. Quality: flash-lite returned the full season-by-season list plus the analysis (358 output tokens on average), while flash was truncated mid-sentence at exactly 32 output tokens on every run. Latency: flash-lite averaged 1.79 s against 5.25 s for flash, about 3 times faster even producing far more text. On cost the two are nearly equal ($0.15 vs $0.11 per 1000 calls), and flash only looks cheaper because it stopped early, its lower cost is an artefact of a broken answer, not a real advantage. Here the smaller, cheaper model is clearly the better choice in this case.",
#   'Q3': 'Arabic costs the most per word: 2.25 tokens/word, against 1.64 for French and 1.22 for English — about 1.8 times (nearly double) the English rate. The Arabic sentence was the shortest in both characters (49) and words (8) and still needed 18 tokens, as many as the longer French one, because the tokenizer is English-centric and breaks Arabic script into many sub-word pieces. Practical consequence for a Moroccan company deploying an Arabic assistant: every interaction consumes roughly twice the tokens of its English equivalent, so it costs about two times more per request, fills the context window faster and can be slower. Arabic-language AI is structurally more expensive to run, and that must be budgeted for.',
#   'Q4': 'My method never measured if the model told the truth. I only logged answer length, latency and cost, and read the text by eye, nothing in the code checks, rounds and opponents were correct.'},
#  'tables': {'comparison': [{'model': 'gemini-3.5-flash-lite',
#     'run': 1,
#     'in_tokens': 106,
#     'out_tokens': 364,
#     'latency_s': 1.88,
#     'cost_usd': 0.000156},
#    {'model': 'gemini-3.5-flash-lite',
#     'run': 2,
#     'in_tokens': 106,
#     'out_tokens': 352,
#     'latency_s': 1.79,
#     'cost_usd': 0.000151},
#    {'model': 'gemini-3.5-flash-lite',
#     'run': 3,
#     'in_tokens': 106,
#     'out_tokens': 359,
#     'latency_s': 1.71,
#     'cost_usd': 0.000154},
#    {'model': 'gemini-3.5-flash',
#     'run': 1,
#     'in_tokens': 106,
#     'out_tokens': 32,
#     'latency_s': 4.68,
#     'cost_usd': 0.000112},
#    {'model': 'gemini-3.5-flash',
#     'run': 2,
#     'in_tokens': 106,
#     'out_tokens': 32,
#     'latency_s': 7.34,
#     'cost_usd': 0.000112},
#    {'model': 'gemini-3.5-flash',
#     'run': 3,
#     'in_tokens': 106,
#     'out_tokens': 32,
#     'latency_s': 3.72,
#     'cost_usd': 0.000112}],
#   'summary': [{'model': 'gemini-3.5-flash',
#     'out_tokens': 32.0,
#     'latency_s': 5.246667,
#     'cost_usd': 0.000112,
#     'cost_per_1000_calls': 0.11},
#    {'model': 'gemini-3.5-flash-lite',
#     'out_tokens': 358.333333,
#     'latency_s': 1.793333,
#     'cost_usd': 0.000154,
#     'cost_per_1000_calls': 0.15}],
#   'tokens': [{'language': 'English',
#     'characters': 65,
#     'words': 9,
#     'input_tokens': 11,
#     'tokens_per_word': 1.22},
#    {'language': 'French',
#     'characters': 88,
#     'words': 11,
#     'input_tokens': 18,
#     'tokens_per_word': 1.64},
#    {'language': 'Arabic',
#     'characters': 49,
#     'words': 8,
#     'input_tokens': 18,
#     'tokens_per_word': 2.25}]},
#  'extra': {'task': "Recap FC Barcelona's Champions League exits every season since 2015/16 and analyse why they keep failing to win a 6th title.",
#   'prompt': '\nList, for FC Barcelona, every UEFA Champions League campaign from the 2015/16 season through the 2025/26 season. For each season give exactly: the season, the round in which Barcelona were eliminated, and the club that eliminated them. Present it as one line per season. Then, in 3 to 4 sentences, identify the recurring pattern behind these eliminations. Be precise if you are not sure about a specific season, say so instead of guessing.\n',
#   'distinct_T0': 3,
#   'distinct_T15': 3},
#  'call_log': [{'text': 'OK',
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 0.0,
#    'in_tokens': 6,
#    'out_tokens': 1,
#    'latency_s': 2.11,
#    'cost_usd': 1e-06,
#    'cached': False},
#   {'text': 'A language model is an AI system trained on vast amounts of text to predict, generate, and understand human language based on statistical patterns.',
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 0.0,
#    'in_tokens': 11,
#    'out_tokens': 27,
#    'latency_s': 0.58,
#    'cost_usd': 1.2e-05,
#    'cached': False},
#   {'text': '**Project Title:** *“AgroEcho: Acoustic Crop Health Monitoring using Edge AI”*\n\n### The Concept\nInstead of using visual cameras (drones or satellites) to detect crop diseases and pest infestations—which is expensive, power-hungry, and often only detects damage *after* it’s visible—this project uses **bioacoustics and tiny machine learning (TinyML)** to listen to the crops and soil. \n\nYou train an AI model to recognize the specific acoustic signatures of:\n1. **Pests chewing:** Different insects (like rootworms or stem borers) create distinct microscopic vibrations and chewing sounds within plants.\n2. **Water stress (Cavitation):** When plants are severely dehydrated, the water columns inside their xylem vessels snap, creating tiny ultrasonic clicking noises.\n3. **Beneficial activity:** The ambient sound of a healthy soil microbiome (earthworms, beneficial insects).\n\n### How It Works (Student Implementation)\n* **The Hardware:** A low-cost microcontroller (like an Arduino Nano 33 BLE Sense or ESP32), a contact microphone (piezoelectric sensor) stuck into the soil or clamped gently to a plant stem, and a small solar panel.\n* **The AI:** Record audio samples of healthy plants, thirsty plants, and infested plants. Extract audio features (like Mel-frequency cepstral coefficients - MFCCs) and train a lightweight classifier (using TensorFlow Lite) to run directly on the microcontroller.\n* **The Output:** The device runs locally in a potted plant or greenhouse testbed, using an LED or a cheap LoRa/Wi-Fi module to alert the farmer *days before* visual symptoms appear (e.g., "Pest detected in Sector 3" or "Irrigation needed: Plant is cavitating").\n\n### Why this is a great student project:\n* **Interdisciplinary:** Combines biology (plant physiology/entomology), hardware engineering (sensors/acoustics), and computer science (Edge AI/TinyML).\n* **Novelty:** Most student projects just reuse standard plant-leaf image classification datasets. Listening to plants is a cutting-edge real-world agricultural research area.\n* **Low Cost:** Piezo microphones and microcontrollers are very inexpensive compared to thermal cameras or drone setups.',
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 0.0,
#    'in_tokens': 15,
#    'out_tokens': 474,
#    'latency_s': 2.88,
#    'cost_usd': 0.000191,
#    'cached': False},
#   {'text': '**Project Title:** *“AgriSound: Acoustic Monitoring of Crop Health and Pest Infestation Using Edge AI”*\n\n### The Core Idea\nInstead of using expensive drones or computer vision (which struggle to see inside dense foliage, underground, or inside stems), this project uses **bioacoustics and machine learning** to "listen" to a farm. \n\nStudents train a lightweight AI model to classify audio recordings captured by cheap, solar-powered Raspberry Pi nodes placed around a farm. The system listens for specific acoustic signatures:\n1. **Pest Activity:** The chewing sounds of caterpillars, borers, or locusts eating leaves and stems.\n2. **Water Stress:** Ultrasonic cavitation sounds—the literal "screaming" of plant xylem tubes snapping as water becomes scarce and tension increases inside the plant.\n3. **Beneficial Insects:** The hum of bees and pollinators, indicating healthy ecosystem activity.\n\n### Why It’s Great for Students:\n* **Interdisciplinary:** Combines biology (plant physiology, entomology), hardware (microphones, IoT, solar power), and software (audio processing, machine learning).\n* **Cost-Effective:** A basic prototype can be built using a $10 microphone, a Raspberry Pi or Arduino, and pre-recorded audio datasets (or sounds recorded from classroom plants). \n* **Real-World Impact:** Farmers get an early-warning system for hidden pests and drought stress *days* before visual symptoms appear, reducing pesticide use and saving water.\n* **Scalable Complexity:** \n  * *Beginner level:* Train a classifier on existing audio files using Python (Librosa + Scikit-learn).\n  * *Advanced level:* Deploy the model to an edge-computing device in a greenhouse with a dashboard alerting the farmer via SMS.',
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 1.5,
#    'in_tokens': 15,
#    'out_tokens': 370,
#    'latency_s': 2.74,
#    'cost_usd': 0.00015,
#    'cached': False},
#   {'text': '**Project Title:** *“BuzzWatch: Acoustic AI for Early Colony Collapse & Disease Detection in Backyard Beehives”*\n\n### The Core Idea\nInstead of monitoring massive crop fields (which has been heavily explored), this project focuses on **pollinator health** using audio AI. \n\nStudents deploy a low-cost microcontroller (like an ESP32 with an attached microphone) inside or near a beehive to continuously record the colony’s "hum." An AI model (a Convolutional Neural Network trained on audio spectrograms) analyzes the sound frequencies in real-time to detect the subtle acoustic signatures of agricultural stressors *before* visual symptoms appear.\n\n### What the AI Detects:\n1. **Queenlessness:** When a hive loses its queen, the overall frequency and pattern of the buzzing changes dramatically within hours (often described as a distressed "roar").\n2. **Swarming Preparation:** Bees make specific "piping" and "tooting" sounds days before a swarm leaves the hive.\n3. **Parasitic Stress (Varroa Mites):** Certain erratic flutter frequencies indicate the colony is struggling with mite infestations or pesticide poisoning from nearby farms.\n\n### Tech Stack for Students\n* **Hardware:** Raspberry Pi Pico W or ESP32-CAM ($10-$15), USB microphone, waterproof housing, solar panel.\n* **Data/Software:** Python, TensorFlow Lite, or Edge Impulse (a beginner-friendly platform for embedded machine learning).\n* **Dataset:** Students can use publicly available audio datasets (like the *Zenodo Bee Sound Dataset*) to train the model, then fine-tune it with local recordings.\n\n### Why this is a great student project:\n* **High Impact:** Honeybees are essential to agricultural yields (pollinating 1/3 of the human diet). It bridges the gap between tech, biology, and local food security.\n* **Feasible Scope:** Audio data is much lighter and easier to process on cheap edge devices than high-res video imagery (computer vision).\n* **Interdisciplinary:** It combines machine learning, ecology, hardware engineering, and data visualization (e.g., a dashboard showing hive "mood" over time). \n* **Scalable Presentation:** Students can build a physical prototype, show a live dashboard, and play audio clips of "happy bees" vs. "stressed bees" during their presentation.',
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 0.0,
#    'in_tokens': 15,
#    'out_tokens': 488,
#    'latency_s': 2.71,
#    'cost_usd': 0.000197,
#    'cached': False},
#   {'text': '**Project Title:** *“AgroEcho: Acoustic Crop Health Monitoring via Edge-AI”*\n\n### The Concept\nInstead of using visual cameras (drones or satellites) to monitor crop health—which is expensive, struggles with early disease detection, and is blocked by canopy foliage—this project uses **bioacoustics and machine learning** to "listen" to plants and the ecosystem within a farm. \n\nPlants under stress (e.g., drought, pest infestation, or nutrient deficiency) undergo physical changes, such as cavitation (micro-ruptures in the water-transporting xylem vessels due to dehydration) or changes in the feeding sounds of pests. \n\n### How It Works (The Student Implementation)\n1. **The Hardware:** A low-cost directional microphone or a piezoelectric sensor (contact mic attached to a plant stem) connected to an edge-computing device like a Raspberry Pi or Arduino Nano 33 BLE.\n2. **The Data Collection:** Students record audio samples of healthy plants vs. stressed plants (e.g., deliberately withholding water from a potted tomato plant or introducing common pests like caterpillars).\n3. **The AI Model:** Train a lightweight Convolutional Neural Network (CNN) using spectrograms (visual representations of the audio frequencies) to classify audio clips into categories: *Healthy, Thirsty, Pest Attack, or Nutrient Deficient.*\n4. **The Actionable Output:** The Edge-AI device triggers a localized alert (e.g., an SMS via Twilio or an MQTT message to a farmer\'s dashboard) pinpointing *exactly* which zone or row needs attention.\n\n### Why This is Great for a Student Project:\n* **Interdisciplinary:** Combines biology/botany, hardware engineering, audio signal processing, and machine learning.\n* **Originality:** Most AI-ag projects rely on standard computer vision (detecting sick leaves via photos). Acoustic monitoring is an emerging, cutting-edge field in precision agriculture.\n* **Scalable & Budget-Friendly:** You don\'t need expensive drone equipment; a few potted plants, cheap contact mics, and a laptop are enough to build a working prototype.\n* **Real-World Impact:** It offers a non-destructive, continuous, 24/7 monitoring solution that can detect stress *before* it becomes visible to the human eye.',
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 1.5,
#    'in_tokens': 15,
#    'out_tokens': 482,
#    'latency_s': 3.08,
#    'cost_usd': 0.000194,
#    'cached': False},
#   {'text': '**Project Title:** *Micro-Livestock Guardian: Acoustic Monitoring of Stress and Disease in Backyard Poultry/Small-Scale Livestock*\n\n### **The Core Idea**\nInstead of focusing on massive commercial farms (which are already heavily digitized), this project targets small-scale, backyard, or urban farmers. Students build an edge-AI acoustic sensor system (using a low-cost microcontroller like an ESP32 or Raspberry Pi Pico) that listens to the vocalizations and respiratory sounds of small livestock (like chickens, rabbits, or goats) to detect early signs of stress, illness, or predator threats before physical symptoms appear.\n\n### **How It Works**\n1. **Data Collection (The Dataset):** Students record audio of healthy animals versus distressed animals (e.g., heat stress, respiratory illness like mycoplasma, or panic from a nearby predator). \n2. **AI/ML Model:** Train a lightweight audio classification model (using TensorFlow Lite for Microcontrollers) to recognize specific frequency patterns and acoustic signatures associated with distress calls or abnormal breathing (wheezing/coughing).\n3. **The Intervention:** When the AI detects a high probability of distress, it sends a localized alert (via Wi-Fi/Bluetooth or a simple SMS/app notification) to the farmer, suggesting specific actions (e.g., "Check coop temperature," or "Quarantine Chicken #4").\n\n### **Why This is a Great Student Project:**\n* **Social Impact (Democratizing AI):** It brings smart-farming technology to hobbyists, educational farms, and subsistence farmers who can\'t afford expensive commercial AgriTech.\n* **Feasibility:** Audio data is much easier and cheaper to collect and process than high-resolution computer vision datasets. \n* **Multidisciplinary:** It combines biology/animal husbandry (understanding animal behavior), hardware engineering (microphone placement, power management), and machine learning (audio feature extraction using Mel-frequency cepstral coefficients (MFCCs)).\n* **Scalability:** A capstone team could build a working prototype for under $50 in hardware.',
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 0.0,
#    'in_tokens': 15,
#    'out_tokens': 426,
#    'latency_s': 2.5,
#    'cost_usd': 0.000172,
#    'cached': False},
#   {'text': '**Project Title:** *“AgroEcho: Acoustic Crop Health Monitoring Using Edge AI”*\n\n### The Core Idea\nInstead of using computer vision (drones/cameras) to detect plant diseases or pests—which is heavily saturated—this project uses **bioacoustics and machine learning** to "listen" to crops. \n\nJust like humans listen to a person\'s chest with a stethoscope, this project uses low-cost contact microphones (piezoelectric sensors) stuck into the stems or soil of plants to detect the micro-vibrations and acoustic signals of **water stress (cavitation)** and **pest activity (chewing/boring insects)** before visible symptoms appear.\n\n### How It Works (The Tech Stack)\n1. **Sensors:** Inexpensive contact microphones or accelerometers attached to plant stems (e.g., in a greenhouse tomato plant or corn stalk).\n2. **Edge AI:** A microcontroller like a Raspberry Pi Pico or Arduino Nano 33 BLE Sense running a lightweight TinyML model.\n3. **The Data:** Plants under drought stress make distinct snapping/popping sounds at ultrasonic frequencies as water columns break in their xylem (cavitation). Caterpillars and borers make specific chewing frequencies.\n4. **The Output:** The device classifies the audio in real-time and sends a simple alert (via Wi-Fi/Bluetooth) to the farmer’s phone: *"Zone 3: Early drought stress detected"* or *"Zone 1: Potential stem borer activity."*\n\n### Why This is Great for a Student Project:\n* **Novelty:** Most students just train a ResNet on leaf photos. Audio-based plant diagnostics are cutting-edge agricultural research.\n* **Interdisciplinary:** Combines biology (plant physiology/hydraulics), hardware (sensors/soldering), and software (audio feature extraction like MFCCs and machine learning classification).\n* **Low Cost:** Piezo microphones cost pennies compared to multispectral agricultural cameras.\n* **Real Impact:** Early detection of drought stress or hidden borers can save crops days before visual damage occurs, using a fraction of the power required for continuous video monitoring.',
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 1.5,
#    'in_tokens': 15,
#    'out_tokens': 446,
#    'latency_s': 2.91,
#    'cost_usd': 0.00018,
#    'cached': False},
#   {'text': '2015/16: Eliminated in the Quarter-finals by Atlético Madrid\n2016/17: Eliminated in the Quarter-finals by Juventus\n2017/18: Eliminated in the Quarter-finals by Roma\n2018/19: Eliminated in the Semi-finals by Liverpool\n2019/20: Eliminated in the Quarter-finals by Bayern Munich\n2020/21: Eliminated in the Round of 16 by Paris Saint-Germain\n2021/22: Eliminated in the Group stage (dropped to Europa League), though technically eliminated from the Champions League by Bayern Munich and Benfica\n2022/23: Eliminated in the Group stage (dropped to Europa League), though technically eliminated from the Champions League by Bayern Munich and Inter Milan\n2023/24: Eliminated in the Quarter-finals by Paris Saint-Germain\n2024/25: *Uncertain / Season not yet completed or fully played at the time of this prompt\'s scope*\n2025/26: *Uncertain / Season not yet completed or fully played at the time of this prompt\'s scope*\n\nA recurring pattern behind Barcelona\'s modern Champions League eliminations is their vulnerability to historic collapses, often referred to as "remontadas," where commanding aggregate leads or promising positions are dramatically squandered away from home. In many of these high-profile exits—such as against Roma, Liverpool, and Juventus—the team exhibited a fragile collective mentality when placed under intense defensive pressure and high-tempo pressing. Additionally, tactical rigidity and defensive lapses routinely exposed them against physically robust and tactically disciplined European opponents.',
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 0.7,
#    'in_tokens': 106,
#    'out_tokens': 364,
#    'latency_s': 1.88,
#    'cost_usd': 0.000156,
#    'cached': False},
#   {'text': "2015/16: Eliminated in the Quarter-finals by Atlético Madrid\n2016/17: Eliminated in the Quarter-finals by Juventus\n2017/18: Eliminated in the Quarter-finals by Roma\n2018/19: Eliminated in the Semi-finals by Liverpool\n2019/20: Eliminated in the Quarter-finals by Bayern Munich\n2020/21: Eliminated in the Round of 16 by Paris Saint-Germain\n2021/22: Eliminated in the Group stage (dropped to Europa League), though technically knocked out of the Champions League by Bayern Munich and Benfica in the group phase\n2022/23: Eliminated in the Group stage (dropped to Europa League), with group elimination sealed primarily by Bayern Munich and Internazionale\n2023/24: Eliminated in the Quarter-finals by Paris Saint-Germain\n2024/25: Not yet determined (season in progress; group/league phase ongoing)\n2025/26: Not yet determined (future season)\n\nThe recurring pattern behind FC Barcelona's modern Champions League eliminations is their vulnerability to catastrophic defensive collapses, particularly away from Camp Nou. Whether suffering historic three-goal and four-goal aggregate comebacks against clubs like Roma, Liverpool, and Juventus, or suffering heavy defeats to elite sides like Bayern Munich and Paris Saint-Germain, the team repeatedly failed to manage high-pressure leads and high-intensity opponents. This tactical fragility eventually caused them to regress from regular title contenders into frequent early-knockout and group-stage casualties.",
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 0.7,
#    'in_tokens': 106,
#    'out_tokens': 352,
#    'latency_s': 1.79,
#    'cost_usd': 0.000151,
#    'cached': False},
#   {'text': "2015/16: Eliminated in the Quarter-finals by Atlético Madrid\n2016/17: Eliminated in the Quarter-finals by Juventus\n2017/18: Eliminated in the Quarter-finals by Roma\n2018/19: Eliminated in the Semi-finals by Liverpool\n2019/20: Eliminated in the Quarter-finals by Bayern Munich\n2020/21: Eliminated in the Round of 16 by Paris Saint-Germain\n2021/22: Eliminated in the Group stage (dropped to UEFA Europa League; eliminated in the Quarter-finals by Eintracht Frankfurt)\n2022/23: Eliminated in the Group stage (dropped to UEFA Europa League; eliminated in the Knockout round play-offs by Manchester United)\n2023/24: Eliminated in the Quarter-finals by Paris Saint-Germain\n2024/25: The 2024/25 UEFA Champions League season is ongoing; elimination details are not yet finalized.\n2025/26: The 2025/26 UEFA Champions League season has not yet occurred; elimination details are not yet available.\n\nThe recurring pattern behind Barcelona's Champions League eliminations during this period is their vulnerability to historic, high-scoring collapses in away or knockout fixtures. Whether facing tactical masterclasses or intense pressing from elite opponents like Roma, Liverpool, and Bayern Munich, the team frequently failed to defend aggregate leads or maintain defensive composure under intense pressure. This fragility often manifested as sudden psychological collapses on the road, turning seemingly comfortable positions into heavy and decisive defeats.",
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 0.7,
#    'in_tokens': 106,
#    'out_tokens': 359,
#    'latency_s': 1.71,
#    'cost_usd': 0.000154,
#    'cached': False},
#   {'text': 'Here is the list of FC Barcelona’s UEFA Champions League campaigns from the 2015/16 season through the 2025/',
#    'model': 'gemini-3.5-flash',
#    'temperature': 0.7,
#    'in_tokens': 106,
#    'out_tokens': 32,
#    'latency_s': 4.68,
#    'cost_usd': 0.000112,
#    'cached': False},
#   {'text': '* **2015/16:** Quarter-finals, Atlético Madrid\n* **2016/17:** Quarter-finals, Juventus',
#    'model': 'gemini-3.5-flash',
#    'temperature': 0.7,
#    'in_tokens': 106,
#    'out_tokens': 32,
#    'latency_s': 7.34,
#    'cost_usd': 0.000112,
#    'cached': False},
#   {'text': 'Here is the list of FC Barcelona’s UEFA Champions League campaigns from the 2015/16 season through the 2025/',
#    'model': 'gemini-3.5-flash',
#    'temperature': 0.7,
#    'in_tokens': 106,
#    'out_tokens': 32,
#    'latency_s': 3.72,
#    'cost_usd': 0.000112,
#    'cached': False},
#   {'text': 'That',
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 0.0,
#    'in_tokens': 11,
#    'out_tokens': 1,
#    'latency_s': 18.22,
#    'cost_usd': 2e-06,
#    'cached': False},
#   {'text': 'C',
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 0.0,
#    'in_tokens': 18,
#    'out_tokens': 1,
#    'latency_s': 24.4,
#    'cost_usd': 2e-06,
#    'cached': False},
#   {'text': 'بال',
#    'model': 'gemini-3.5-flash-lite',
#    'temperature': 0.0,
#    'in_tokens': 18,
#    'out_tokens': 1,
#    'latency_s': 21.38,
#    'cost_usd': 2e-06,
#    'cached': False}],
#  'created': '2026-09-15 20:36'}

# %% [markdown]
# ---
# ## Going further (optional, not graded)
#
# - Run your prompt at `temperature=0.0` and `temperature=2.0`, ten times each, and plot the
#   number of distinct answers. Where does it stop being useful?
# - Add a `system=` instruction to `ask()` (for example: *"You always answer in exactly three
#   bullet points."*). Does it hold across the three runs?
# - Take the answer you liked least and try to fix it **by changing the prompt only**.
#   Keep both prompts — you will see in Lab 6 how to measure that improvement properly.
